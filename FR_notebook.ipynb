# %%
import tensorflow as tf
from tensorflow import keras

#from keras.models import load_model

# %%
# seems to be this issue: https://stackoverflow.com/questions/63484172/tensorflow-load-data-bad-marshal-data

model = tf.keras.models.load_model('models/facenet_keras.h5')
#model = load_model('models/facenet_keras.h5')

#summarize input and output shape
print(model.inputs)
print(model.outputs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a37c071da9d4> in <module>
#       1 # seems to be this issue: https://stackoverflow.com/questions/63484172/tensorflow-load-data-bad-marshal-data
#       2
# ----> 3 model = tf.keras.models.load_model('models/facenet_keras.h5')
#       4 #model = load_model('models/facenet_keras.h5')
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
#     184     filepath = path_to_string(filepath)
#
# ...

# %%
import mtcnn

# %%
from keras_facenet import FaceNet

# %%
embedder = FaceNet()

# %%
import cv2

test_img = cv2.imread('images/yj_photo.jpg', 0)

# %%
cv2.imshow('image',test_img)

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Gets a detection dict for each face
# in an image. Each one has the bounding box and
# face landmarks (from mtcnn.MTCNN) along with
# the embedding from FaceNet.
detections = embedder.extract(test_img, threshold=0.95)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f83fc6ff5a9a> in <module>
#       3 # face landmarks (from mtcnn.MTCNN) along with
#       4 # the embedding from FaceNet.
# ----> 5 detections = embedder.extract(test_img, threshold=0.95)
#
# ~/anaconda3/lib/python3.8/site-packages/keras_facenet/__init__.py in extract(self, filepath_or_image, threshold)
#      92             with an "embedding" vector.
#      93         """
# ---> 94         detections, crops = self.crop(filepath_or_image, threshold=threshold)
#      95         if not detections:
#      96             return []
#
# ~/anaconda3/lib/python3.8/site-packages/keras_facenet/__init__.py in crop(self, filepath_or_image, threshold)
#      74         else:
#      75             image = filepath_or_image
# ...

# %%
# If you have pre-cropped images, you can skip the
# detection step.
embeddings = embedder.embeddings(test_img)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input Tensor("input_1_1:0", shape=(None, None, None, 3), dtype=float32), but it was called on an input with incompatible shape (None, 160, 160).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-14214fe93070> in <module>
#       1 # If you have pre-cropped images, you can skip the
#       2 # detection step.
# ----> 3 embeddings = embedder.embeddings(test_img)
#
# ~/anaconda3/lib/python3.8/site-packages/keras_facenet/__init__.py in embeddings(self, images)
#     111         images = [cv2.resize(image, (s, s)) for image in images]
#     112         X = np.float32([self._normalize(image) for image in images])
# --> 113         embeddings = self.model.predict(X)
#     114         return embeddings
#     115
#
# ...
